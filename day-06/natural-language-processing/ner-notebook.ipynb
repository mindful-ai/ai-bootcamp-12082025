# %%
import nltk

# Download required packages (only first time)
nltk.download("punkt")
nltk.download("averaged_perceptron_tagger")
nltk.download("maxent_ne_chunker")
nltk.download("words")

# Example text
text = "Apple is looking to invest $1 billion in India by 2025, said Tim Cook in New Delhi."

# Tokenize into words
words = nltk.word_tokenize(text)

# Part-of-speech tagging
pos_tags = nltk.pos_tag(words)

# Named entity recognition using NLTK's chunker
ner_tree = nltk.ne_chunk(pos_tags, binary=False)

# Print named entities
print("Named Entities:")
for subtree in ner_tree:
    if hasattr(subtree, "label"):  # Check if it's a named entity
        entity = " ".join([token for token, pos in subtree.leaves()])
        label = subtree.label()
        print(f"{entity} -> {label}")
# Out:
# C:\Users\mindf\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\nltk\metrics\association.py:26: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.3.2)
#   from scipy.stats import fisher_exact
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mindf\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\mindf\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\mindf\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\mindf\AppData\Roaming\nltk_data...
# ...

# %%
import spacy

# %%
import spacy

# Load pre-trained English model
# install it using -> python -m spacy download en_core_web_sm

nlp = spacy.load("en_core_web_sm")

# Example text
text = "Apple is looking to invest $1 billion in India by 2025, said Tim Cook in New Delhi."

# Process the text
doc = nlp(text)

# Print named entities
print("Entities, their labels, and positions:")
for ent in doc.ents:
    print(f"{ent.text} -> {ent.label_} (start: {ent.start_char}, end: {ent.end_char})")
# Out:
# Entities, their labels, and positions:
# Apple -> ORG (start: 0, end: 5)
# $1 billion -> MONEY (start: 27, end: 37)
# India -> GPE (start: 41, end: 46)
# 2025 -> DATE (start: 50, end: 54)
# Tim Cook -> PERSON (start: 61, end: 69)
# New Delhi -> GPE (start: 73, end: 82)
