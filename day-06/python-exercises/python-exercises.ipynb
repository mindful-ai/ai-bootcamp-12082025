# %% [markdown]
# ### map()

# %%
C = [12, 34, 45, 56, 100]

# %%
F = []
for t in C:
    F.append(t * 1.8 + 32)
F
# Out:
# [53.6, 93.2, 113.0, 132.8, 212.0]

# %%
F1 = map(lambda t : t * 1.8 + 32, C)
F1

# %%
list(F1)
# Out:
# [53.6, 93.2, 113.0, 132.8, 212.0]
