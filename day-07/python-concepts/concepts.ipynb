# %%
import pickle

# Example object to pickle
data = {'name': 'Alice', 'age': 25, 'city': 'Bengaluru'}

# Pickling (serialization)
with open('data.pkl', 'wb') as file:
    pickle.dump(data, file)

# %%
# Unpickling (deserialization)
with open('data.pkl', 'rb') as file:
    loaded_data = pickle.load(file)

print(loaded_data)  # Output: {'name': 'Alice', 'age': 25, 'city': 'Bengaluru'}
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Bengaluru'}

# %%
t1 = (1, 2, 3)
t2 = ('red', 'green', 'blue')

# %%
d = dict(zip(t1, t2))

# %%
d
# Out:
# {1: 'red', 2: 'green', 3: 'blue'}

# %%
d.items()
# Out:
# dict_items([(1, 'red'), (2, 'green'), (3, 'blue')])

# %%
list(zip(*d.items()))
# Out:
# [(1, 2, 3), ('red', 'green', 'blue')]
